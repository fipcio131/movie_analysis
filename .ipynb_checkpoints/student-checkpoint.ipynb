# %% [markdown]
# # Final Project Submission
#
# Please fill out:
# * Student name: Filip Szafranski
# * Student pace: self paced
# * Scheduled project review date/time:
# * Instructor name: Jeff Herman
# * Blog post URL:

# %% [markdown]
# What type of films are currently doing the best at the box office?

# %%
# Your code here - remember to use markdown cells for comments as well!

# %% [markdown]
# Problems and questions:
# * check which genres are the most popular and profitable - which dbs to join?
# * the most profitable movies and studios
# * actors vs. profit
#
# * what kind of data visulaization to use?

# %% [markdown]
# ### AVAILABLE DATABASES ANALYSIS

# %% [markdown]
# Uploading libraries and available databases using pandas and read_csv method.

# %%
#Uploading libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
db_movie_budgets = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')

# %%
db_movie = pd.read_csv('zippedData/tmdb.movies.csv.gz')

# %%
db_movie_reviews = pd.read_csv('zippedData/rt.reviews.tsv.gz', sep='\t', encoding="latin-1")
db_movie_info = pd.read_csv('zippedData/rt.movie_info.tsv.gz', sep='\t')

# %%
db_ratings = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
db_title_basics = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
db_name_basics = pd.read_csv('zippedData/imdb.name.basics.csv.gz')
db_titles_principals = pd.read_csv('zippedData/imdb.title.principals.csv.gz')

# %%
db_movie_gross = pd.read_csv('zippedData/bom.movie_gross.csv.gz')

# %%
db_movie_gross['year'] = pd.to_datetime(db_movie_gross['year']).dt.year

# %% [markdown]
# ### CHECKING FOR MISSING VALUES

# %%
db_ratings.isna().sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64

# %%
db_movie_budgets.isna().sum()
# Out:
# id                   0
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
db_movie_reviews.isna().sum()
# Out:
# id                0
# review         5563
# rating        13517
# fresh             0
# critic         2722
# top_critic        0
# publisher       309
# date              0
# dtype: int64

# %% [markdown]
# ### DATA CLEANUP AND PROCESSING
#
# db_ratings analysis - grouping and sorting values

# %%
#movies with the best ratings based on number of votes above 10.000/movie

db_best_ratings = db_ratings[db_ratings['numvotes'] > 10000].sort_values(by=['averagerating', 'numvotes'], ascending=False)
db_best_ratings.head(15)
# Out:
#           tconst  averagerating  numvotes
# 9643   tt5813916            9.3    100568
# 10198  tt5354160            9.3     18470
# 49629  tt2170667            9.3     17308
# 36889  tt2592910            9.2     41560
# 60112  tt5275892            8.9     14946
# 63498  tt1375666            8.8   1841066
# 59785  tt4154796            8.8    441135
# 14415  tt3417422            8.8     24326
# 58930  tt7019842            8.8     10903
# 15820  tt7060344            8.8     10518
# 47362  tt6316138            8.7     26743
# 64553  tt6148156            8.7     18704
# 24920  tt0816692            8.6   1299334
# 71431  tt1424432            8.6     55318
# 59127  tt8291224            8.6     30292

# %% [markdown]
# Processing databases

# %%
#Left join on tconst columns
df_joined_movie = db_best_ratings.join(db_title_basics.set_index('tconst'), how='inner', on='tconst')
df_joined_movie
# Out:
#           tconst  averagerating  numvotes                   primary_title  \
# 9643   tt5813916            9.3    100568                 The Mountain II
# 10198  tt5354160            9.3     18470                        Aynabaji
# 49629  tt2170667            9.3     17308                          Wheels
# 36889  tt2592910            9.2     41560          CM101MMXI Fundamentals
# 60112  tt5275892            8.9     14946           O.J.: Made in America
# ...          ...            ...       ...                             ...
# 58672  tt3165608            1.8     17476         Justin Bieber's Believe
# 55902  tt1702443            1.6     74978  Justin Bieber: Never Say Never
# 17877  tt4458206            1.5     26723               Code Name: K.O.Z.
# 9185   tt4009460            1.5     14221                Saving Christmas
# 39053  tt7221896            1.3     36986  Cumali Ceber: Allah Seni Alsin
#
#                        original_title  start_year  runtime_minutes  \
# 9643                           Dag II        2016            135.0
# 10198                        Aynabaji        2016            147.0
# 49629                          Wheels        2014            115.0
# 36889          CM101MMXI Fundamentals        2013            139.0
# 60112           O.J.: Made in America        2016            467.0
# ...                               ...         ...              ...
# 58672         Justin Bieber's Believe        2013             92.0
# 55902  Justin Bieber: Never Say Never        2011            105.0
# 17877                  Kod Adi K.O.Z.        2015            114.0
# 9185                 Saving Christmas        2014             79.0
# 39053  Cumali Ceber: Allah Seni Alsin        2017            100.0
#
#                             genres
# 9643              Action,Drama,War
# 10198       Crime,Mystery,Thriller
# 49629                        Drama
# 36889           Comedy,Documentary
# 60112  Biography,Crime,Documentary
# ...                            ...
# 58672            Documentary,Music
# 55902            Documentary,Music
# 17877                Crime,Mystery
# 9185                 Comedy,Family
# 39053                       Comedy
#
# [2677 rows x 8 columns]

# %%
#Split "genres" column values
df_joined_movie['genres'] = df_joined_movie['genres'].map(lambda x: x.split(','))

# %%
# Exploding genres column comma separated values to find out mean rating for each genre
df_joined_movie_genres = df_joined_movie.explode('genres')
df_joined_movie_genres
# Out:
#           tconst  averagerating  numvotes                   primary_title  \
# 9643   tt5813916            9.3    100568                 The Mountain II
# 9643   tt5813916            9.3    100568                 The Mountain II
# 9643   tt5813916            9.3    100568                 The Mountain II
# 10198  tt5354160            9.3     18470                        Aynabaji
# 10198  tt5354160            9.3     18470                        Aynabaji
# ...          ...            ...       ...                             ...
# 17877  tt4458206            1.5     26723               Code Name: K.O.Z.
# 17877  tt4458206            1.5     26723               Code Name: K.O.Z.
# 9185   tt4009460            1.5     14221                Saving Christmas
# 9185   tt4009460            1.5     14221                Saving Christmas
# 39053  tt7221896            1.3     36986  Cumali Ceber: Allah Seni Alsin
#
#                        original_title  start_year  runtime_minutes   genres
# 9643                           Dag II        2016            135.0   Action
# 9643                           Dag II        2016            135.0    Drama
# 9643                           Dag II        2016            135.0      War
# 10198                        Aynabaji        2016            147.0    Crime
# 10198                        Aynabaji        2016            147.0  Mystery
# ...                               ...         ...              ...      ...
# 17877                  Kod Adi K.O.Z.        2015            114.0    Crime
# 17877                  Kod Adi K.O.Z.        2015            114.0  Mystery
# 9185                 Saving Christmas        2014             79.0   Comedy
# 9185                 Saving Christmas        2014             79.0   Family
# 39053  Cumali Ceber: Allah Seni Alsin        2017            100.0   Comedy
#
# [6877 rows x 8 columns]

# %%
#Creating new db with mean values
df_genres_summary = df_joined_movie_genres.groupby(by ='genres').mean().sort_values(by = 'averagerating', ascending=True)

#Adding new column with values count
df_genres_summary['item_count'] = df_joined_movie_genres.groupby('genres')['genres'].count()

#New database with genres rating and reset index
df_best_genres = df_genres_summary.reset_index()

# %%
df_best_genres
# Out:
#          genres  averagerating       numvotes   start_year  runtime_minutes  \
# 0        Horror       5.919061   55445.914365  2014.132597        98.839779
# 1        Family       6.295455   87513.375000  2013.295455       106.363636
# 2       Fantasy       6.310000  125971.560000  2014.040000       110.395000
# 3       Mystery       6.335273   83141.636364  2014.261818       105.861818
# 4      Thriller       6.338685   83079.112186  2014.065764       107.787234
# 5        Comedy       6.407982   72827.547672  2013.742794       104.779379
# 6        Action       6.414501  131392.248974  2014.143639       115.051984
# 7        Sci-Fi       6.435023  192040.792627  2014.364055       112.138249
# 8     Adventure       6.524481  170242.690871  2014.184647       111.655602
# 9       Romance       6.531068   56306.961165  2013.446602       109.645631
# 10        Crime       6.545940   77454.198718  2014.027778       111.594017
# 11      Western       6.600000  153851.733333  2013.400000       115.000000
# 12        Music       6.754930   64098.338028  2014.028169       111.788732
# 13        Drama       6.759731   70501.202694  2013.978451       112.974411
# 14      Musical       6.771429   83778.857143  2014.285714       135.357143
# 15    Animation       6.860000  102749.114286  2014.071429        95.907143
# 16          War       6.972500   53639.350000  2014.225000       116.250000
# 17        Sport       7.021277   68124.191489  2013.829787       118.978723
# 18      History       7.087234   70546.255319  2014.734043       121.489362
# 19    Biography       7.100000   82735.799163  2014.782427       118.376569
# 20  Documentary       7.442857   22160.389610  2013.714286       107.493506
# 21         News       8.300000   23264.000000  2016.000000        96.000000
#
#     item_count
# 0          362
# 1           88
# 2          200
# 3          275
# 4          517
# 5          902
# 6          731
# 7          217
# 8          482
# 9          412
# 10         468
# 11          15
# 12          71
# 13        1485
# 14          14
# 15         140
# 16          40
# 17          47
# 18          94
# 19         239
# 20          77
# 21           1

# %%
#Narrowing down db to movie between 2000 - 2020
df_best_genres_2000 = df_best_genres[df_best_genres['start_year'] >= 2000]

# %%
#Remove $ and , characters from certain columns
db_movie_budgets[['domestic_gross', 'production_budget', 'worldwide_gross']] = db_movie_budgets[['domestic_gross', 'production_budget', 'worldwide_gross']].applymap(lambda x: x[1:].replace(',', ''))

# %%
#Convert columns data type from obj to numeric type - in64
db_movie_budgets[['domestic_gross', 'production_budget', 'worldwide_gross']] = db_movie_budgets[['domestic_gross', 'production_budget', 'worldwide_gross']].astype('int64')

# %%
#Creating a new column with domestic gross/budget ratio
db_movie_budgets['domestic gross/budget ratio'] = db_movie_budgets['domestic_gross']/db_movie_budgets['production_budget']

# %%
#Creating a new column with worldwide gross/budget ratio
db_movie_budgets['worldwide gross/budget ratio'] = db_movie_budgets['worldwide_gross']/db_movie_budgets['production_budget']

# %%
# Converting release_date from object to date format
db_movie_budgets['release_date'] = pd.to_datetime(db_movie_budgets['release_date'])
db_movie_budgets['release_date'] = db_movie_budgets['release_date'].dt.year

# %%
#Narrowing down db to movie between 2000 - 2020
db_movie_budgets_2000 = db_movie_budgets[db_movie_budgets['release_date'] >= 2000]

# %%
db_movie_budgets_2000
# Out:
#       id  release_date                                        movie  \
# 0      1          2009                                       Avatar
# 1      2          2011  Pirates of the Caribbean: On Stranger Tides
# 2      3          2019                                 Dark Phoenix
# 3      4          2015                      Avengers: Age of Ultron
# 4      5          2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..           ...                                          ...
# 5776  77          2004                              The Mongol King
# 5777  78          2018                                       Red 11
# 5779  80          2005                Return to the Land of Wonders
# 5780  81          2015                         A Plague So Pleasant
# 5781  82          2005                            My Date With Drew
#
#       production_budget  domestic_gross  worldwide_gross  \
# 0             425000000       760507625       2776345279
# 1             410600000       241063875       1045663875
# 2             350000000        42762350        149762350
# 3             330600000       459005868       1403013963
# 4             317000000       620181382       1316721747
# ...                 ...             ...              ...
# 5776               7000             900              900
# 5777               7000               0                0
# 5779               5000            1338             1338
# 5780               1400               0                0
# 5781               1100          181041           181041
#
#       domestic gross/budget ratio  worldwide gross/budget ratio
# 0                        1.789430                      6.532577
# 1                        0.587101                      2.546673
# 2                        0.122178                      0.427892
# 3                        1.388403                      4.243841
# 4                        1.956408                      4.153696
# ...                           ...                           ...
# 5776                     0.128571                      0.128571
# 5777                     0.000000                      0.000000
# 5779                     0.267600                      0.267600
# 5780                     0.000000                      0.000000
# 5781                   164.582727                    164.582727
#
# [4387 rows x 8 columns]

# %%
db_movie_profits = db_movie_budgets.groupby('release_date').mean().sort_values('release_date')
db_movie_profits_index = db_movie_profits.reset_index()
db_movie_profits
# Out:
#                      id  production_budget  domestic_gross  worldwide_gross  \
# release_date
# 1915          78.000000       1.100000e+05    1.000000e+07     1.100000e+07
# 1916          19.500000       2.929535e+05    4.000000e+06     4.000000e+06
# 1920          84.000000       1.000000e+05    3.000000e+06     3.000000e+06
# 1925          38.500000       2.072500e+06    1.000000e+07     1.550000e+07
# 1927          85.000000       2.000000e+06    0.000000e+00     0.000000e+00
# ...                 ...                ...             ...              ...
# 2016          49.643836       4.097370e+07    5.042387e+07     1.313614e+08
# 2017          51.422619       5.003073e+07    6.222259e+07     1.692240e+08
# 2018          53.286713       4.813886e+07    7.378870e+07     1.824786e+08
# 2019          51.791045       5.273896e+07    4.280029e+07     9.965411e+07
# 2020          45.666667       9.400000e+07    0.000000e+00     0.000000e+00
#
#               domestic gross/budget ratio  worldwide gross/budget ratio
# release_date
# 1915                            90.909091                    100.000000
# 1916                            20.000000                     20.000000
# 1920                            30.000000                     30.000000
# 1925                            23.602826                     46.051805
# 1927                             0.000000                      0.000000
# ...                                   ...                           ...
# 2016                             1.599537                      3.426034
# 2017                             1.980350                      4.136917
# 2018                             2.077434                      3.945939
# 2019                             1.224815                      2.243176
# 2020                             0.000000                      0.000000
#
# [96 rows x 6 columns]

# %%
#Adding new column with gross profit sum for each year
db_movie_profits['worldwide_gross_total'] = db_movie_budgets.groupby('release_date')['worldwide_gross'].sum()

# %%
#Adding new column with movies count for each year
db_movie_profits['count_total'] = db_movie_budgets.groupby('release_date')['movie'].count()

# %%
db_movie_profits
# Out:
#                      id  production_budget  domestic_gross  worldwide_gross  \
# release_date
# 1915          78.000000       1.100000e+05    1.000000e+07     1.100000e+07
# 1916          19.500000       2.929535e+05    4.000000e+06     4.000000e+06
# 1920          84.000000       1.000000e+05    3.000000e+06     3.000000e+06
# 1925          38.500000       2.072500e+06    1.000000e+07     1.550000e+07
# 1927          85.000000       2.000000e+06    0.000000e+00     0.000000e+00
# ...                 ...                ...             ...              ...
# 2016          49.643836       4.097370e+07    5.042387e+07     1.313614e+08
# 2017          51.422619       5.003073e+07    6.222259e+07     1.692240e+08
# 2018          53.286713       4.813886e+07    7.378870e+07     1.824786e+08
# 2019          51.791045       5.273896e+07    4.280029e+07     9.965411e+07
# 2020          45.666667       9.400000e+07    0.000000e+00     0.000000e+00
#
#               domestic gross/budget ratio  worldwide gross/budget ratio  \
# release_date
# 1915                            90.909091                    100.000000
# 1916                            20.000000                     20.000000
# 1920                            30.000000                     30.000000
# 1925                            23.602826                     46.051805
# 1927                             0.000000                      0.000000
# ...                                   ...                           ...
# 2016                             1.599537                      3.426034
# 2017                             1.980350                      4.136917
# 2018                             2.077434                      3.945939
# 2019                             1.224815                      2.243176
# 2020                             0.000000                      0.000000
#
#               worldwide_gross_total  count_total
# release_date
# 1915                       11000000            1
# 1916                        8000000            2
# 1920                        3000000            1
# 1925                       31000000            2
# 1927                              0            1
# ...                             ...          ...
# 2016                    28768152741          219
# 2017                    28429629005          168
# 2018                    26094444899          143
# 2019                     6676825346           67
# 2020                              0            3
#
# [96 rows x 8 columns]

# %%
#Narrowing down db to movie between 2000 - 2020
df_joined_movie_genres_2000 = df_joined_movie_genres[df_joined_movie_genres['start_year'] >= 2000]

# %%
db_viz_gross = db_movie_gross.sort_values(by = 'domestic_gross', ascending=False).head(15)
db_viz_gross
# Out:
#                                 title studio  domestic_gross foreign_gross  \
# 1872     Star Wars: The Force Awakens     BV     936700000.0       1,131.6
# 3080                    Black Panther     BV     700100000.0     646900000
# 3079           Avengers: Infinity War     BV     678800000.0       1,369.5
# 1873                   Jurassic World   Uni.     652300000.0       1,019.4
# 727             Marvel's The Avengers     BV     623400000.0     895500000
# 2758         Star Wars: The Last Jedi     BV     620200000.0     712400000
# 3082                    Incredibles 2     BV     608600000.0     634200000
# 2323     Rogue One: A Star Wars Story     BV     532200000.0     523900000
# 2759      Beauty and the Beast (2017)     BV     504000000.0     759500000
# 2324                     Finding Dory     BV     486300000.0     542300000
# 1875          Avengers: Age of Ultron     BV     459000000.0     946400000
# 729             The Dark Knight Rises     WB     448100000.0     636800000
# 1131  The Hunger Games: Catching Fire    LGF     424700000.0     440300000
# 3081   Jurassic World: Fallen Kingdom   Uni.     417700000.0     891800000
# 0                         Toy Story 3     BV     415000000.0     652000000
#
#       year
# 1872  1970
# 3080  1970
# 3079  1970
# 1873  1970
# 727   1970
# 2758  1970
# 3082  1970
# 2323  1970
# 2759  1970
# 2324  1970
# 1875  1970
# 729   1970
# 1131  1970
# 3081  1970
# 0     1970

# %% [markdown]
# ### DATA VISUALIZATION

# %%
# %matplotlib inline
plot_style = 'fivethirtyeight'
time_range = (2000,2021)

# %%
db_viz_gross_studio = db_movie_gross[['studio', 'domestic_gross']].groupby('studio').sum().reset_index().sort_values(by = 'domestic_gross', ascending=False).head(15)

# %%
db_movie_roi = db_movie_budgets_2000.sort_values(by = 'worldwide gross/budget ratio', ascending=False).head(15)

# %%
viz = db_movie_gross[['studio', 'domestic_gross']].groupby('studio').sum().reset_index().sort_values(by = 'domestic_gross', ascending=False).head(15)

# %%
df_best_genres_2000 = df_best_genres_2000.replace('News', 'Documentary')
df_best_genres_2000
# Out:
#          genres  averagerating       numvotes   start_year  runtime_minutes  \
# 0        Horror       5.919061   55445.914365  2014.132597        98.839779
# 1        Family       6.295455   87513.375000  2013.295455       106.363636
# 2       Fantasy       6.310000  125971.560000  2014.040000       110.395000
# 3       Mystery       6.335273   83141.636364  2014.261818       105.861818
# 4      Thriller       6.338685   83079.112186  2014.065764       107.787234
# 5        Comedy       6.407982   72827.547672  2013.742794       104.779379
# 6        Action       6.414501  131392.248974  2014.143639       115.051984
# 7        Sci-Fi       6.435023  192040.792627  2014.364055       112.138249
# 8     Adventure       6.524481  170242.690871  2014.184647       111.655602
# 9       Romance       6.531068   56306.961165  2013.446602       109.645631
# 10        Crime       6.545940   77454.198718  2014.027778       111.594017
# 11      Western       6.600000  153851.733333  2013.400000       115.000000
# 12        Music       6.754930   64098.338028  2014.028169       111.788732
# 13        Drama       6.759731   70501.202694  2013.978451       112.974411
# 14      Musical       6.771429   83778.857143  2014.285714       135.357143
# 15    Animation       6.860000  102749.114286  2014.071429        95.907143
# 16          War       6.972500   53639.350000  2014.225000       116.250000
# 17        Sport       7.021277   68124.191489  2013.829787       118.978723
# 18      History       7.087234   70546.255319  2014.734043       121.489362
# 19    Biography       7.100000   82735.799163  2014.782427       118.376569
# 20  Documentary       7.442857   22160.389610  2013.714286       107.493506
# 21  Documentary       8.300000   23264.000000  2016.000000        96.000000
#
#     item_count
# 0          362
# 1           88
# 2          200
# 3          275
# 4          517
# 5          902
# 6          731
# 7          217
# 8          482
# 9          412
# 10         468
# 11          15
# 12          71
# 13        1485
# 14          14
# 15         140
# 16          40
# 17          47
# 18          94
# 19         239
# 20          77
# 21           1

# %% [markdown]
# ### MARKET SIZE AND GROSS PROFIT BY YEAR
# Data analysis for 1920 - 2020

# %%
with plt.style.context('fivethirtyeight'):
    fig = plt.figure(figsize=(18,6))

    ax1 = fig.add_subplot(121)
    ax2 = fig.add_subplot(122)
    
    ax1.plot(db_movie_profits['count_total'])

    ax1.tick_params('x', labelrotation=90)
    ax1.set_ylabel('Number of released movies', rotation = 'vertical')
    ax1.set_xlabel('Year')
    ax1.set_title('Total Number of Released Movies by Year')
    ax1.set_xlim()
    
#     ax2=ax1.twinx()

    ax2.plot(db_movie_profits['worldwide_gross_total'], color = 'red')
    ax2.tick_params('x', labelrotation=90)
    ax2.set_xlabel('Year')
    ax2.set_ylabel('Total gross (10B)', rotation = 'vertical')
    ax2.set_title('Total Gross Profit By Year')
    ax2.set_xlim()
#     plt.ticklabel_format(axis="y", style="plain", scilimits=(0,0))
    
    plt.savefig('viz/global trends.png', bbox_inches="tight")

# %% [markdown]
# ### ROI, BUDGET AND GROSS PROFIT

# %%
with plt.style.context('fivethirtyeight'):
    fig = plt.figure(figsize=(18,6))

    ax1 = fig.add_subplot(121)
    ax2 = fig.add_subplot(122)
    ax1.plot(db_movie_profits[['domestic gross/budget ratio','worldwide gross/budget ratio']])

    ax1.tick_params('x', labelrotation=90)
    ax1.set_ylabel('ROI Ratio', rotation = 'vertical')
    ax1.set_xlabel('Year', labelpad=15)
    ax1.set_title('ROI Ratio')
    ax1.legend(['domestic ROI','worldwide ROI'])
    ax1.set_xlim(time_range)
    ax1.set_ylim(0,10)

    ax2.plot(db_movie_profits[['domestic_gross','worldwide_gross','production_budget']])
    ax2.tick_params('x', labelrotation=90)
    ax2.set_xlabel('Year', labelpad=15)
    ax2.set_ylabel('Mean gross profit/production', rotation = 'vertical', labelpad=15)
    ax2.set_title('15 most profitable studios - domestic market')
    ax2.legend(['mean domestic gross','mean worldwide gross','mean production budget'])
    ax2.set_title('Mean Gross Profit and Production Budget')
    ax2.set_xlim(time_range), ax2.set_ylim(0,3e8)
    
    plt.savefig('viz/STUDIOS AND MOVIES PROFITABILITY 2000 - 2020.png', bbox_inches="tight")

# %% [markdown]
# ### 15 MOST PROFITABLE STUDIOS AND MOVIES 1920 - 2020

# %%
with plt.style.context('fivethirtyeight'):
    fig = plt.figure(figsize=(18,6))

    ax1 = fig.add_subplot(122)
    ax2 = fig.add_subplot(121)
    ax1.bar('title', 'domestic_gross', data = db_viz_gross)

    ax1.tick_params('x', labelrotation=90)
    ax1.set_ylabel('Domestic gross profit', rotation = 'vertical', labelpad=15)
    ax1.set_xlabel('Movie tile')
    ax1.set_title('15 Most Profitable Movies - Domestic Market')

    ax2.bar(db_viz_gross_studio['studio'], db_viz_gross_studio['domestic_gross'], color = 'goldenrod')
    ax2.tick_params('x', labelrotation=90)
    ax2.set_xlabel('Studio', labelpad=40)
    ax2.set_ylabel('Total gross profit/studio', rotation = 'vertical', labelpad=15)
    ax2.set_title('15 Most Profitable Studios - Domestic Market')
    
    plt.savefig('viz/15 MOST PROFITABLE STUDIOS AND MOVIES 1920 - 2020.png', bbox_inches="tight")

# %%
#Dropping 'My Big Fat Greek Wedding' due to incorrect data
db_movie_roi = db_movie_roi.drop(index = db_movie_roi[db_movie_roi.movie == 'My Big Fat Greek Wedding'].index)

# %%
with plt.style.context('fivethirtyeight'):
    fig = plt.figure(figsize=(18,6))

    ax1 = fig.add_subplot(121)
    ax2 = fig.add_subplot(122)
    ax1.barh('movie', 'worldwide gross/budget ratio', data = db_movie_roi)

    ax1.tick_params('x', labelrotation=90)
    ax1.set_ylabel('Movie', rotation = 'vertical', labelpad=15)
    ax1.set_xlabel('ROI Ratio', labelpad=45)
    ax1.set_title('15 Biggest ROI Movies')
    ax1.invert_yaxis()

    ax2.barh('movie', 'production_budget', data = db_movie_roi, color = 'mediumspringgreen')
    ax2.tick_params('x', labelrotation=90)
    ax2.set_xlabel('Production Budget', labelpad=15)
#     ax2.set_yticklabels([])
#     ax2.set_ylabel('Movie', rotation = 'vertical', labelpad=15)
    ax2.set_title('15 Biggest ROI Movies - Production Budget')
    ax2.invert_yaxis()
    
    plt.savefig('viz/MOst Profitable movies.png', bbox_inches="tight")

# %% [markdown]
# ### GENRES ANALYSIS

# %%
with plt.style.context('fivethirtyeight'):
    fig = plt.figure(figsize=(18,6))

    ax1 = fig.add_subplot(121)
    ax2 = fig.add_subplot(122)
    ax1.barh('genres', 'item_count', data = df_best_genres_2000, color = 'orangered')

    ax1.tick_params('x', labelrotation=90)
    ax1.set_ylabel('Genre', rotation = 'vertical')
    ax1.set_xlabel('Movie Tile')
    ax1.set_title('Most Popular Genres')

    ax2.barh(df_best_genres_2000['genres'], df_best_genres_2000['averagerating'])
    ax2.tick_params('x', labelrotation=90)
    ax2.set_xlabel('Studio')
    ax2.set_ylabel('Genre', rotation = 'vertical')
    ax2.set_title('Highest Rated Genres')
    
    plt.savefig('viz/Genres.png', bbox_inches="tight")

# %% [markdown]
# ### BUDGET SIZE ANALYSIS

# %%
with plt.style.context('fivethirtyeight'):
    fig = plt.figure(figsize=(18,6))

    ax1 = fig.add_subplot(121)
    ax2 = fig.add_subplot(122)
    ax1.scatter('production_budget','worldwide_gross', data = db_movie_budgets_2000)

    #scatter plot - budget vs gross
    ax1.tick_params('x', labelrotation=90)
    ax1.set_ylabel('Worldwide Gross Profit ($B)', rotation = 'vertical', labelpad=15)
    ax1.set_xlabel('production budget', labelpad=15)
    ax1.set_title('Budget vs. Profit')

    #the biggest ROI can be achieved with a smaller budget
    ax2.scatter('production_budget','worldwide gross/budget ratio', data = db_movie_budgets_2000, color = 'salmon')
    ax2.tick_params('x', labelrotation=90)
    ax2.set_xlabel('production budget', labelpad=15)
    ax2.set_ylabel('Worldwide ROI', rotation = 'vertical', labelpad=15)
    ax2.set_title('ROI vs. Budget')
    ax2.set_xlim(0, 4.5e8), ax2.set_ylim(0,7e1)
    
    plt.savefig('viz/Budget Analysis.png', bbox_inches="tight")
